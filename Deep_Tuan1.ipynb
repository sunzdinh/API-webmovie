# %% [markdown]
# <a href="https://colab.research.google.com/github/sunzdinh/API-webmovie/blob/main/Deep_Tuan1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy
import numpy as np
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)

# %%
#cau1
a = np.random.randint(20, size=(3,3))
print(a)
result = np.all(a)
print(result)
# Out:
# [[ 1 19 10]
#  [11 17  9]
#  [16  4  5]]
# True

# %%
a = np.random.randint(20, size=(3,3))
print(a)
result= np.any(a)
print(result)
# Out:
# [[ 3 17  8]
#  [ 5 11  7]
#  [ 7 15  7]]
# True
